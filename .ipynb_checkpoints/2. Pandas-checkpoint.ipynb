# %% [markdown]
# # Intro to Pandas
# Pandas is the primary Python library for doing basic data analysis. If you are a data scientist, much of your life will be spent manipulating data in Pandas. Pandas provides a nice layering on top of NumPy to make data analysis much easier. In particular, the primary data structure, the DataFrame, provides labels for both the rows and the columns. This makes for much easier access to the elements within.
#
# ### City of Houston Employee Data
# We will use City of Houston Employee data found on the city's [open data website][1]
#
# [1]: http://data.houstontx.gov/

# %%
import pandas as pd

# %%
# read in the data
emp = pd.read_csv('data/employee.csv')

# %% [markdown]
# ### Use the `head` method to shorten output
# By default it returns the first 5 rows.

# %%
emp.head()
# Out:
#                    title                            dept   salary   race  \
# 0         POLICE OFFICER   Houston Police Department-HPD  45279.0  White
# 1      ENGINEER/OPERATOR   Houston Fire Department (HFD)  63166.0  White
# 2  SENIOR POLICE OFFICER   Houston Police Department-HPD  66614.0  Black
# 3               ENGINEER  Public Works & Engineering-PWE  71680.0  Asian
# 4              CARPENTER    Houston Airport System (HAS)  42390.0  White
#
#   gender  experience
# 0   Male           1
# 1   Male          34
# 2   Male          32
# 3   Male           4
# 4   Male           3

# %% [markdown]
# Use an integer for another number of rows

# %%
emp.head(7)
# Out:
#                                       title                            dept  \
# 0                            POLICE OFFICER   Houston Police Department-HPD
# 1                         ENGINEER/OPERATOR   Houston Fire Department (HFD)
# 2                     SENIOR POLICE OFFICER   Houston Police Department-HPD
# 3                                  ENGINEER  Public Works & Engineering-PWE
# 4                                 CARPENTER    Houston Airport System (HAS)
# 5  DEPUTY ASSISTANT DIRECTOR (EXECUTIVE LEV  Public Works & Engineering-PWE
# 6                              FIRE FIGHTER   Houston Fire Department (HFD)
#
#      salary      race gender  experience
# 0   45279.0     White   Male           1
# 1   63166.0     White   Male          34
# 2   66614.0     Black   Male          32
# 3   71680.0     Asian   Male           4
# 4   42390.0     White   Male           3
# 5  107962.0     White   Male          23
# 6   52644.0  Hispanic   Male           9

# %% [markdown]
# # Components of the DataFrame
# The vast majority of an analysis takes place inside a DataFrame. There are three components to a DataFrame, the **index**, the **columns** and the **data** or **values**. The index labels the rows, the column names label the columns and the data are the actual values that we manipulate during an analysis.
#
# ![anatomy](./images/Components of a DataFrame.png)

# %% [markdown]
# ### DataFrame attributes and methods
# Like NumPy arrays, much of the power of the DataFrame is done with method calls.

# %% [markdown]
# ## DataFrame Attributes
#
# ### Column data types
# A very important attribute is **`dtypes`** which returns the data type of each column. It is imperative to know the data type of each column.
#
# ### Main data types
# * bool
# * int
# * float
# * object
# * datetime
#
# The vast majority of columns will be one of the above data types

# %% [markdown]
# ### DataFrame attributes and methods
# Like NumPy arrays, much of the power of the DataFrame is done with method calls. Let's find the data types of each column:

# %%
emp.dtypes
# Out:
# title          object
# dept           object
# salary        float64
# race           object
# gender         object
# experience      int64
# dtype: object

# %%
emp.shape
# Out:
# (1535, 6)

# %% [markdown]
# # DataFrame methods
# A powerful method to find all the summary statistics is the **`describe`** column.

# %%
# by default, it only outputs summary stats for numeric columns
emp.describe()
# Out:
#               salary   experience
# count    1535.000000  1535.000000
# mean    56278.745928    13.786319
# std     20328.441253     9.963621
# min     24960.000000     0.000000
# 25%     42000.000000     5.000000
# 50%     55461.000000    12.000000
# 75%     66614.000000    22.000000
# max    210588.000000    58.000000

# %% [markdown]
# ### Summary of string columns

# %%
emp.describe(include='object')
# Out:
#                  title                           dept   race gender
# count             1535                           1535   1535   1535
# unique             236                              6      5      2
# top     POLICE OFFICER  Houston Police Department-HPD  White   Male
# freq               184                            570    542   1135

# %% [markdown]
# # Categorical vs Continuous
# Data can be categorized into two broad types. Data that is discrete and countable is called **categorical**. These variables usually have strings as values but sometimes numeric values like year or age may be considered categorical. **Continuous** variables on the other hand are always numeric. Lot size or sale price are examples of continuous variables.

# %% [markdown]
# ## Selecting Single Columns of Data - A Series
# Each column of data may be selected with the brackets by passing the column name as a string. A pandas Series is a single dimensional data structure with an index and values. It has no columns. It is very similar to a DataFrame.

# %%
# Select a single column
salary = emp['salary']
salary.head(10)
# Out:
# 0     45279.0
# 1     63166.0
# 2     66614.0
# 3     71680.0
# 4     42390.0
# 5    107962.0
# 6     52644.0
# 7    180416.0
# 8     30347.0
# 9     55269.0
# Name: salary, dtype: float64

# %% [markdown]
# ![](images/Components of a Series.png)

# %% [markdown]
# ## Series and DataFrame methods overlap
# Series are just a single column of data and most of its methods are in common with the DataFrame.

# %% [markdown]
# ### Counting the values of categorical data
# The **`value_counts`** method (unique to Series) is valuable for getting an idea of the distribution of categorical variables.

# %%
race = emp['race']

# %%
race.value_counts()
# Out:
# White              542
# Black              518
# Hispanic           381
# Asian               87
# Native American      7
# Name: race, dtype: int64

# %% [markdown]
# ## Get the percentage of occurrence by using `normalize=True`

# %%
race.value_counts(normalize=True)
# Out:
# White              0.353094
# Black              0.337459
# Hispanic           0.248208
# Asian              0.056678
# Native American    0.004560
# Name: race, dtype: float64

# %%
dept = emp['dept']
dept.value_counts()
# Out:
# Houston Police Department-HPD     570
# Houston Fire Department (HFD)     365
# Public Works & Engineering-PWE    341
# Houston Airport System (HAS)      103
# Health & Human Services           103
# Parks & Recreation                 53
# Name: dept, dtype: int64

# %% [markdown]
# ## Many of the same methods exist for NumPy arrays and Pandas DataFrames and Series

# %%
salary.max()
# Out:
# 210588.0

# %%
salary.min()
# Out:
# 24960.0

# %% [markdown]
# ## The arithmetic and comparison operators work the same

# %%
bonus = 10000
(salary + bonus).head()
# Out:
# 0    55279.0
# 1    73166.0
# 2    76614.0
# 3    81680.0
# 4    52390.0
# Name: salary, dtype: float64

# %%
# determine if salary is greater than 100k
(salary > 100000).head()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# Name: salary, dtype: bool

# %% [markdown]
# # Practice
# * Select columns as Series.
# * Call DataFrame/Series Methods
# * Use **shift + tab + tab** to read the documentation

# %%
# your code her
sal = emp['salary']
sal.describe()
# Out:
# count      1535.000000
# mean      56278.745928
# std       20328.441253
# min       24960.000000
# 25%       42000.000000
# 50%       55461.000000
# 75%       66614.000000
# max      210588.000000
# Name: salary, dtype: float64

# %%
emp[salary== emp['salary'].max()]
# Out:
#                                    title                           dept  \
# 145  ASSOCIATE EMS PHYSICIAN DIRECTOR,MD  Houston Fire Department (HFD)
#
#        salary   race gender  experience
# 145  210588.0  White   Male          15

# %%
emp[salary== emp['salary'].min()]
# Out:
#              title                           dept   salary   race  gender  \
# 347  CAR ATTENDANT  Houston Police Department-HPD  24960.0  Black  Female
#
#      experience
# 347           0

# %% [markdown]
# # Grouping and Aggregating
# One of the most common operations during an analysis is to divide the data into groups and aggregate some other dimension of data.
#
# ![](images/split-apply-combine small.png)
#
# ### The three components of a groupby aggregation
# * **Grouping Column** - Column whose unique values form groups
# * **Aggregating Column** - Column whose values we are going to aggregate (return a single value from)
# * **Aggregating Function** - The type of aggregation. i.e. sum, min, max, median, etc...
#
# ## Syntax
#
# ### `df.groupby('grouping column').agg({'aggregating column': 'aggregating function'})`
#
#
#
# # Find the average salary by race
#
# ### Identify grouping column
# ### Identify aggregating column
# ### Identify aggregating function

# %%
# force to be integer to remove decimals
emp.groupby('race').agg({'salary': 'mean'}).astype('int')
# Out:
#                  salary
# race
# Asian             60143
# Black             50366
# Hispanic          52533
# Native American   64562
# White             63834

# %% [markdown]
# # What is an aggregating function?
# The formal definition of an aggregating function is one that summarizes many numbers by a single value. Sum, min, max, median, etc... are all aggregating functions.

# %% [markdown]
# # Group by multiple columns
# # Aggregate multiple columns
# # Use multiple aggregating functions
# When using multiple of any of the three components of a groupby, use a list.

# %%
emp.groupby(['race', 'gender']).agg({'salary': ['mean', 'max']}).astype('int')
# Out:
#                        salary
#                          mean     max
# race            gender
# Asian           Female  58304   95950
#                 Male    60622  163228
# Black           Female  48133  150416
#                 Male    51853  186192
# Hispanic        Female  44216   96157
#                 Male    55493  165216
# Native American Female  58844   68299
#                 Male    68850   81239
# White           Female  66415  178331
#                 Male    63439  210588

# %%
emp.groupby(['race', 'gender']).agg({'salary': ['mean', 'max'], 'experience': ['size', 'sum', 'mean']}).astype('int')
# Out:
#                        salary         experience
#                          mean     max       size   sum mean
# race            gender
# Asian           Female  58304   95950         18   293   16
#                 Male    60622  163228         69   945   13
# Black           Female  48133  150416        207  2816   13
#                 Male    51853  186192        311  4026   12
# Hispanic        Female  44216   96157        100  1060   10
#                 Male    55493  165216        281  3453   12
# Native American Female  58844   68299          3    51   17
#                 Male    68850   81239          4    63   15
# White           Female  66415  178331         72   958   13
#                 Male    63439  210588        470  7497   15

# %% [markdown]
# # Practice Grouping and aggregating

# %%
# your code here
emp.groupby(['dept', 'gender']).agg({'salary': ['mean', 'max'], 'experience': ['size', 'sum', 'mean']}).astype('int')
# Out:
#                                       salary         experience
#                                         mean     max       size   sum mean
# dept                           gender
# Health & Human Services        Female  48652  103270         77   933   12
#                                Male    59240  180416         26   252    9
# Houston Airport System (HAS)   Female  53730  150416         35   432   12
#                                Male    54124  186192         68   780   11
# Houston Fire Department (HFD)  Female  52853   96668         21   241   11
#                                Male    60394  210588        344  4803   13
# Houston Police Department-HPD  Female  52432  104455        144  2085   14
#                                Male    63131  199596        426  6992   16
# Parks & Recreation             Female  41043   83916         17   263   15
#                                Male    38662   85055         36   391   10
# Public Works & Engineering-PWE Female  51023  178331        106  1224   11
#                                Male    49839  141948        235  2766   11

# %%
emp.groupby(['dept', 'gender','title']).agg({'salary': ['mean', 'max'], 'experience': ['size', 'sum', 'mean']}).astype('int')
# Out:
#                                                                               salary  \
#                                                                                 mean
# dept                           gender title
# Health & Human Services        Female ADMINISTRATION MANAGER                   84437
#                                       ADMINISTRATIVE ASSISTANT                 43319
#                                       ADMINISTRATIVE ASSOCIATE                 36358
#                                       ADMINISTRATIVE COORDINATOR               65589
#                                       BREASTFEEDING PEER COUNSELOR             28170
#                                       BUREAU CHIEF,PUBLIC HEALTH              103270
#                                       CLINIC ASSISTANT                         30597
#                                       COMMUNITY LIAISON                        48928
#                                       COMMUNITY RELATIONS SPECIALIST           31470
#                                       COUNSELOR                                45884
#                                       CUSTOMER SERVICE CLERK                   30644
#                                       CUSTOMER SERVICE REPRESENTATIVE I        30347
#                                       CUSTOMER SERVICE REPRESENTATIVE II       39052
#                                       CUSTOMER SERVICE REPRESENTATIVE III      36992
#                                       DENTAL ASSISTANT                         31678
#                                       DIVISION MANAGER (EXECUTIVE LEVEL)       94149
#                                       FINANCIAL ANALYST IV                     69597
#                                       HUMAN SERVICE PROGRAM MANAGER            63785
#                                       LABORATORY MANAGER                       81849
#                                       LICENSED VOCATIONAL NURSE                48984
#                                       MANAGEMENT ANALYST IV                    66560
#                                       MICROBIOLOGIST I                         33821
#                                       NUTRITION SERVICES CHIEF                 66178
#                                       NUTRITIONIST CONSULTANT                  58855
#                                       PUBLIC HEALTH DENTIST,DDS               100791
#                                       PUBLIC HEALTH EDUCATOR                   36650
#                                       PUBLIC HEALTH INVESTIGATOR SUPERVISOR    57433
#                                       PUBLIC HEALTH NURSE IV                   76246
#                                       SANITARIAN I                             38709
#                                       SENIOR ACCOUNT CLERK                     34299
# ...                                                                              ...
# Public Works & Engineering-PWE Male   PLANT OPERATOR SUPERVISOR                54995
#                                       PLANT OPERATOR TRAINEE                   31158
#                                       PROCUREMENT SPECIALIST                   52156
#                                       PROJECT MANAGER                          60199
#                                       PROJECT TECHNICIAN III                   45074
#                                       PROJECT TECHNICIAN IV                    50586
#                                       PUBLIC WORKS MAINTENANCE MANAGER         83737
#                                       PUBLIC WORKS MAINTENANCE SECTION CHIEF   57387
#                                       PUBLIC WORKS OPERATIONS MANAGER          86288
#                                       SENIOR ACCOUNT CLERK                     23
# ...                                                                           ...
# Public Works & Engineering-PWE Male   PLANT OPERATOR SUPERVISOR                32
#                                       PLANT OPERATOR TRAINEE                    2
#                                       PROCUREMENT SPECIALIST                    2
#                                       PROJECT MANAGER                          27
#                                       PROJECT TECHNICIAN III                   21
#                                       PROJECT TECHNICIAN IV                     2
#                                       PUBLIC WORKS MAINTENANCE MANAGER         64
#                                       PUBLIC WORKS MAINTENANCE SECTION CHIEF   62
#                                       PUBLIC WORKS OPERATIONS MANAGER          25
#                                       REAL ESTATE MANAGER                      22
#                                       SANITARIAN III                           22
#                                       SECURITY OFFICER INVESTIGATOR             1
#                                       SEMI-SKILLED LABORER                     25
#                                       SENIOR INSPECTOR                        145
#                                       SENIOR INVENTORY MANAGEMENT CLERK        22
#                                       SENIOR PLAN ANALYST                      24
#                                       SENIOR PLANT OPERATOR                    47
#                                       SENIOR PROJECT MANAGER                   42
#                                       SENIOR STAFF ANALYST                     16
#                                       SENIOR UTILITY MECHANIC                  69
#                                       SUPERVISING ENGINEER                     47
#                                       SYSTEMS SUPPORT ANALYST I                12
#                                       SYSTEMS SUPPORT ANALYST IV               11
#                                       TECHNICAL HARDWARE ANALYST I             34
#                                       TECHNICAL HARDWARE ANALYST II            54
#                                       TECHNICAL HARDWARE ANALYST III           59
#                                       UTILITY MECHANIC                          9
#                                       UTILITY WORKER                          395
#                                       WATER SERVICE INSPECTOR I                17
#                                       WATER SERVICE INSPECTOR II                8
#
#
#                                                                              mean
# dept                           gender title
# Health & Human Services        Female ADMINISTRATION MANAGER                   17
#                                       ADMINISTRATIVE ASSISTANT                 15
#                                       ADMINISTRATIVE ASSOCIATE                 32
#                                       ADMINISTRATIVE COORDINATOR                7
#                                       BREASTFEEDING PEER COUNSELOR              1
#                                       BUREAU CHIEF,PUBLIC HEALTH               31
#                                       CLINIC ASSISTANT                         10
#                                       COMMUNITY LIAISON                        16
#                                       COMMUNITY RELATIONS SPECIALIST           18
#                                       COUNSELOR                                 4
#                                       CUSTOMER SERVICE CLERK                   12
#                                       CUSTOMER SERVICE REPRESENTATIVE I         4
#                                       CUSTOMER SERVICE REPRESENTATIVE II       12
#                                       CUSTOMER SERVICE REPRESENTATIVE III       6
#                                       DENTAL ASSISTANT                         18
#                                       DIVISION MANAGER (EXECUTIVE LEVEL)       12
#                                       FINANCIAL ANALYST IV                     11
#                                       HUMAN SERVICE PROGRAM MANAGER             7
#                                       LABORATORY MANAGER                        8
#                                       LICENSED VOCATIONAL NURSE                16
#                                       MANAGEMENT ANALYST IV                     4
#                                       MICROBIOLOGIST I                          1
#                                       NUTRITION SERVICES CHIEF                 23
#                                       NUTRITIONIST CONSULTANT                  17
#                                       PUBLIC HEALTH DENTIST,DDS                 1
#                                       PUBLIC HEALTH EDUCATOR                    1
#                                       PUBLIC HEALTH INVESTIGATOR SUPERVISOR    22
#                                       PUBLIC HEALTH NURSE IV                   24
#                                       SANITARIAN I                              1
#                                       SENIOR ACCOUNT CLERK                     23
# ...                                                                           ...
# Public Works & Engineering-PWE Male   PLANT OPERATOR SUPERVISOR                16
#                                       PLANT OPERATOR TRAINEE                    1
#                                       PROCUREMENT SPECIALIST                    2
#                                       PROJECT MANAGER                           9
#                                       PROJECT TECHNICIAN III                   21
#                                       PROJECT TECHNICIAN IV                     2
#                                       PUBLIC WORKS MAINTENANCE MANAGER         21
#                                       PUBLIC WORKS MAINTENANCE SECTION CHIEF   20
#                                       PUBLIC WORKS OPERATIONS MANAGER          25
#                                       REAL ESTATE MANAGER                      22
#                                       SANITARIAN III                           22
#                                       SECURITY OFFICER INVESTIGATOR             1
#                                       SEMI-SKILLED LABORER                      6
#                                       SENIOR INSPECTOR                         18
#                                       SENIOR INVENTORY MANAGEMENT CLERK        11
#                                       SENIOR PLAN ANALYST                       6
#                                       SENIOR PLANT OPERATOR                    15
#                                       SENIOR PROJECT MANAGER                   10
#                                       SENIOR STAFF ANALYST                     16
#                                       SENIOR UTILITY MECHANIC                   9
#                                       SUPERVISING ENGINEER                     11
#                                       SYSTEMS SUPPORT ANALYST I                12
#                                       SYSTEMS SUPPORT ANALYST IV               11
#                                       TECHNICAL HARDWARE ANALYST I             11
#                                       TECHNICAL HARDWARE ANALYST II            13
#                                       TECHNICAL HARDWARE ANALYST III           11
#                                       UTILITY MECHANIC                          2
#                                       UTILITY WORKER                           10
#                                       WATER SERVICE INSPECTOR I                 5
#                                       WATER SERVICE INSPECTOR II                8
#
# [377 rows x 5 columns]

# %% [markdown]
# # Pivot Tables
# Pivot tables also group and aggregate data, but they do so by placing one of the grouping columns across the columns. For instance, if we were to redo our groupby above with race and gender from two cells above. We could have unique values of gender going across the columns.
#
# The syntax is a little different
#
# #### `df.pivot_table(index='grouping #1', columns='grouping #2', values='agg col', aggfunc='agg function')`

# %%
emp.pivot_table(index='race', columns='gender', values='salary', aggfunc='mean').astype('int')
# Out:
# gender           Female   Male
# race
# Asian             58304  60622
# Black             48133  51853
# Hispanic          44216  55493
# Native American   58844  68850
# White             66415  63439

# %% [markdown]
# Pivot tables generally have more readable output.

# %% [markdown]
# ## Plotting directly from a Pandas DataFrame
# DataFrames conveniently provide a plot method to directly plot without directly using matplotlib.

# %%
# %matplotlib inline

# %%
emp.plot(kind='scatter', x='experience', y='salary',figsize=(12,6))

# %% [markdown]
# # Pandas is better at plotting summarized data (after a pivot)
# Each column is plotted independently. The index becomes the x-axis.

# %%
rg_sal = emp.pivot_table(index='race', columns='gender', values='salary', aggfunc='mean').astype('int')
rg_sal
# Out:
# gender           Female   Male
# race
# Asian             58304  60622
# Black             48133  51853
# Hispanic          44216  55493
# Native American   58844  68850
# White             66415  63439

# %%
rg_sal.plot(kind='bar', figsize=(10, 6))
